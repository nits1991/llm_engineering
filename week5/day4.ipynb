# %% [markdown]
# # RAG Day 4
#
# ## Evaluation!
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Keep in mind how you would evaluate RAG for your business</h2>
#             <span style="color:#181;">This is such an important part of building an accurate and reliable RAG pipeline. And it's applicable to many aspects of solving business problems with LLMs. People are often focused on RAG architecture and RAG frameworks for their business. But even more important: evaluations!</span>
#         </td>
#     </tr>
# </table>

# %%
# !pip install evaluation
# Out:
# Collecting evaluation
#   Downloading evaluation-0.0.2.tar.gz (2.1 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy in /Users/nitin.aggarwal/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from evaluation) (1.26.4)
# Collecting glog (from evaluation)
#   Obtaining dependency information for glog from https://files.pythonhosted.org/packages/39/42/d2502683e9d9086cba5fb741c9b66c72ab1a852d046e1d54d2b80221b69f/glog-0.3.1-py2.py3-none-any.whl.metadata
#   Downloading glog-0.3.1-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting python-gflags>=3.1 (from glog->evaluation)
#   Downloading python-gflags-3.1.2.tar.gz (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 kB 3.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: six in /Users/nitin.aggarwal/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from glog->evaluation) (1.17.0)
# Downloading glog-0.3.1-py2.py3-none-any.whl (7.8 kB)
# Building wheels for collected packages: evaluation, python-gflags
#   Building wheel for evaluation (pyproject.toml) ... done
#   Created wheel for evaluation: filename=evaluation-0.0.2-py3-none-any.whl size=2472 sha256=88bec5f353442ed1b10308f2b2299dc1ad21f1670b81a836a82c29981ff7a1c4
#   Stored in directory: /Users/nitin.aggarwal/Library/Caches/pip/wheels/c2/1b/52/3a6b0472227ed68ab68fb46af7a1c87b11b6685b148b913ddb
#   Building wheel for python-gflags (pyproject.toml) ... done
#   Created wheel for python-gflags: filename=python_gflags-3.1.2-py3-none-any.whl size=57461 sha256=96f2a481bf64b030828e720788e6c3d2481c1775204d7d0dfd94a47900df229f
#   Stored in directory: /Users/nitin.aggarwal/Library/Caches/pip/wheels/05/9a/41/a8f105872405a3453769fb518071f61d27e355b10561461073
# Successfully built evaluation python-gflags
# Installing collected packages: python-gflags, glog, evaluation
# Successfully installed evaluation-0.0.2 glog-0.3.1 python-gflags-3.1.2
#
# [notice] A new release of pip is available: 23.2.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
from evaluation import test

# %%
tests = test.load_tests()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 tests = test.load_tests()
#
# File ~/Documents/llm_learning_2025_bootcamp/llm_engineering/week5/evaluation/test.py:22, in load_tests()
#      20 with open(TEST_FILE, "r", encoding="utf-8") as f:
#      21     for line in f:
# ---> 22         data = json.loads(line.strip())
#      23         tests.append(TestQuestion(**data))
#      24 return tests
#
# File ~/.pyenv/versions/3.12.0/lib/python3.12/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File ~/.pyenv/versions/3.12.0/lib/python3.12/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File ~/.pyenv/versions/3.12.0/lib/python3.12/json/decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
len(tests)
# Out:
# 150

# %%
example = tests[0]
print(example.question)
print(example.category)
print(example.reference_answer)
print(example.keywords)
# Out:
# Who won the prestigious IIOTY award in 2023?
# direct_fact
# Maxine Thompson won the prestigious Insurellm Innovator of the Year (IIOTY) award in 2023.
# ['Maxine', 'Thompson', 'IIOTY']

# %%
from collections import Counter
count = Counter([t.category for t in tests])
count
# Out:
# Counter({'direct_fact': 70,
#          'temporal': 20,
#          'spanning': 20,
#          'comparative': 10,
#          'numerical': 10,
#          'relationship': 10,
#          'holistic': 10})

# %%
from evaluation.eval import evaluate_retrieval, evaluate_answer

# %%
evaluate_retrieval(example)
# Out:
# RetrievalEval(mrr=0.16666666666666666, ndcg=0.28711770538226206, keywords_found=2, total_keywords=3, keyword_coverage=66.66666666666666)

# %%
eval, answer, chunks = evaluate_answer(example)

# %%
eval
# Out:
# AnswerEval(feedback="The answer correctly identifies Maxine as the winner and mentions the IIOTY award in 2023, but it omits Thompson's full name, which is present in the reference. This affects completeness. The relevance is high, as it directly addresses the question about the award winner.", accuracy=5.0, completeness=4.0, relevance=5.0)

# %%
print(eval.feedback)
print(eval.accuracy)
print(eval.completeness)
print(eval.relevance)
# Out:
# The answer correctly identifies Maxine as the winner and mentions the IIOTY award in 2023, but it omits Thompson's full name, which is present in the reference. This affects completeness. The relevance is high, as it directly addresses the question about the award winner.
# 5.0
# 4.0
# 5.0
