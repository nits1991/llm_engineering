# %% [markdown]
# ## RAG Day 3
#
# ### Expert Question Answerer for InsureLLM
#
# LangChain 1.0 implementation of a RAG pipeline.
#
# Using the VectorStore we created last time (with HuggingFace `all-MiniLM-L6-v2`)

# %%
! pip install langchain_ollama
# Out:
# Collecting langchain_ollama
#   Obtaining dependency information for langchain_ollama from https://files.pythonhosted.org/packages/91/08/7be292aee722692b13a93316247b57eefb83d4309f5fdfe636cc47786efe/langchain_ollama-1.0.0-py3-none-any.whl.metadata
#   Downloading langchain_ollama-1.0.0-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.0 in /Users/nitin.aggarwal/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from langchain_ollama) (1.1.0)
# Collecting ollama<1.0.0,>=0.6.0 (from langchain_ollama)
#   Obtaining dependency information for ollama<1.0.0,>=0.6.0 from https://files.pythonhosted.org/packages/47/4f/4a617ee93d8208d2bcf26b2d8b9402ceaed03e3853c754940e2290fed063/ollama-0.6.1-py3-none-any.whl.metadata
#   Downloading ollama-0.6.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/nitin.aggarwal/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.0.0->langchain_ollama) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /Users/nitin.aggarwal/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.0.0->langchain_ollama) (0.4.46)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /Users/nitin.aggarwal/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.0.0->langchain_ollama) (23.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/nitin.aggarwal/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.0.0->langchain_ollama) (2.12.3)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /Users/nitin.aggarwal/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.0.0->langchain_ollama) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/nitin.aggarwal/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.0.0->langchain_ollama) (8.5.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /Users/nitin.aggarwal/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.0.0->langchain_ollama) (4.15.0)
# Requirement already satisfied: httpx>=0.27 in /Users/nitin.aggarwal/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from ollama<1.0.0,>=0.6.0->langchain_ollama) (0.28.1)
# Requirement already satisfied: anyio in /Users/nitin.aggarwal/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from httpx>=0.27->ollama<1.0.0,>=0.6.0->langchain_ollama) (4.11.0)
# Requirement already satisfied: certifi in /Users/nitin.aggarwal/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from httpx>=0.27->ollama<1.0.0,>=0.6.0->langchain_ollama) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /Users/nitin.aggarwal/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from httpx>=0.27->ollama<1.0.0,>=0.6.0->langchain_ollama) (1.0.9)
# Requirement already satisfied: idna in /Users/nitin.aggarwal/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from httpx>=0.27->ollama<1.0.0,>=0.6.0->langchain_ollama) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/nitin.aggarwal/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.27->ollama<1.0.0,>=0.6.0->langchain_ollama) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/nitin.aggarwal/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.0->langchain_ollama) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in /Users/nitin.aggarwal/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain_ollama) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/nitin.aggarwal/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain_ollama) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /Users/nitin.aggarwal/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain_ollama) (2.31.0)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/nitin.aggarwal/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain_ollama) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/nitin.aggarwal/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.0->langchain_ollama) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /Users/nitin.aggarwal/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.0->langchain_ollama) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/nitin.aggarwal/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.0->langchain_ollama) (0.4.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/nitin.aggarwal/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain_ollama) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/nitin.aggarwal/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain_ollama) (2.5.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/nitin.aggarwal/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from anyio->httpx>=0.27->ollama<1.0.0,>=0.6.0->langchain_ollama) (1.3.1)
# Downloading langchain_ollama-1.0.0-py3-none-any.whl (29 kB)
# Downloading ollama-0.6.1-py3-none-any.whl (14 kB)
# Installing collected packages: ollama, langchain_ollama
# Successfully installed langchain_ollama-1.0.0 ollama-0.6.1
#
# [notice] A new release of pip is available: 23.2.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
from dotenv import load_dotenv
# langchain_openai import ChatOpenAI is the LLM abstraction for OpenAI models
from langchain_openai import ChatOpenAI
from langchain_ollama import ChatOllama


from langchain_chroma import Chroma
from langchain_core.messages import SystemMessage, HumanMessage
from langchain_huggingface import HuggingFaceEmbeddings
import gradio as gr
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 4
#       2 # langchain_openai import ChatOpenAI is the LLM abstraction for OpenAI models
#       3 from langchain_openai import ChatOpenAI
# ----> 4 from langchain_ollama import ChatOllama
#       7 from langchain_chroma import Chroma
#       8 from langchain_core.messages import SystemMessage, HumanMessage
#
# ModuleNotFoundError: No module named 'langchain_ollama'

# %%
MODEL = "gpt-4.1-nano"
DB_NAME = "vector_db"
load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### Connect to Chroma; use Hugging Face all-MiniLM-L6-v2

# %%
embeddings = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")
vectorstore = Chroma(persist_directory=DB_NAME, embedding_function=embeddings)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 embeddings = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")
#       2 vectorstore = Chroma(persist_directory=DB_NAME, embedding_function=embeddings)
#
# NameError: name 'HuggingFaceEmbeddings' is not defined

# %% [markdown]
# ### Set up the 2 key LangChain objects: retriever and llm
#
# #### A sidebar on "temperature":
# - Controls how diverse the output is
# - A temperature of 0 means that the output should be predictable
# - Higher temperature for more variety in answers
#
# Some people describe temperature as being like 'creativity' but that's not quite right
# - It actually controls which tokens get selected during inference
# - temperature=0 means: always select the token with highest probability
# - temperature=1 usually means: a token with 10% probability should be picked 10% of the time
#
# Note: a temperature of 0 doesn't mean outputs will always be reproducible. You also need to set a random seed. We will do that in weeks 6-8. (Even then, it's not always reproducible.)
#
# Note 2: if you want creativity, use the System Prompt!

# %%
retriever = vectorstore.as_retriever()
# temprature controls the randomness of the model output, 0 is deterministic higher values more randomness
llm = ChatOpenAI(temperature=0, model_name=MODEL)

# %% [markdown]
# ### These LangChain objects implement the method `invoke()`

# %%
retriever.invoke("Who is Avery?")

# %%
llm.invoke("Who is Avery?")

# %% [markdown]
# ## Time to put this together!

# %%
SYSTEM_PROMPT_TEMPLATE = """
You are a knowledgeable, friendly assistant representing the company Insurellm.
You are chatting with a user about Insurellm.
If relevant, use the given context to answer any question.
If you don't know the answer, say so.
Context:
{context}
"""

# %%
def answer_question(question: str, history):
    docs = retriever.invoke(question)
    context = "\n\n".join(doc.page_content for doc in docs)
    system_prompt = SYSTEM_PROMPT_TEMPLATE.format(context=context)
    response = llm.invoke([SystemMessage(content=system_prompt), HumanMessage(content=question)])
    return response.content

# %%
answer_question("Who is Averi Lancaster?", [])

# %% [markdown]
# ## What could possibly come next? 😂

# %%
gr.ChatInterface(answer_question).launch()

# %% [markdown]
# ## Admit it - you thought RAG would be more complicated than that!!
